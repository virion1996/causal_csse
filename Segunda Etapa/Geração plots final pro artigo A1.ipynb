# %%
import pandas as pd
import json
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfm_use = pd.read_parquet('dfm_use.parquet')
dfm_use
# Out:
#                            name  \
# 1                    Australian
# 2                      Banknote
# 3                        Biodeg
# 4         Breast Cancer Coimbra
# 5       Breast Cancer Wisconsin
# 6                         Churn
# 9                      Diabetes
# 10                          EEg
# 11                       German
# 13                        Heart
# 14                      Heart_2
# 15                        HELOC
# 16                  Horse colic
# 17                    Ionosfera
# 18                          KC2
# 19         liver disorders_bupa
# 20          mammographic_masses
# 21  Mobile Price Classification
# 22                       Monk_1
# 23                       Monk_2
# 24                       Monk_3
# 25                         Musk
# 27                     Phishing
# 28               Room Occupancy
# 29                        Sonar
# 30                     Spambase
# 31                      Student
# 32                      titanic
# 33                        Tokyo
# 34                      twonorm
# 35                 Vertebral_2C
# 37          Votes_Congressional
#
#                                                  path           classe  \
# 1             Australian/Credit_Card_Applications.csv            Class
# 2                Banknote/BankNote_Authentication.csv            class
# 3                              Biodeg/qsar-biodeg.csv            Class
# 4            Breast Cancer Coimbra/breast_coimbra.csv   Classification
# 5           Breast Cancer Wisconsin/breast-cancer.csv        diagnosis
# 6   Churn/WA_Fn-UseC_-Telco-Customer-Churn_process...            Churn
# 9                               Diabetes/diabetes.csv          Outcome
# 10                              EEg/EEG Eye State.csv         Column15
# 11                           German/german_credit.csv          default
# 13                                    Heart/heart.csv           output
# 14                                   Heart/heart2.csv              num
# 15                         HELOC/heloc_dataset_v1.csv  RiskPerformance
# 16                 Horse colic/horseV2_processada.csv          surgery
# 17                           Ionosfera/ionosphere.csv           target
# 18                                        KC2/KC2.csv          defects
# 19                      liver disorders_bupa/bupa.csv         selector
# 20  mammographic_masses/mammographic_masses_cleane...         Severity
# 21  Mobile Price Classification/train_mobile_proce...            range
# 22  ['Monk/monks-1_train.csv', 'Monk/monks-1_test....            Class
# 23  ['Monk/monks-2_train.csv', 'Monk/monks-2_test....            Class
# 24  ['Monk/monks-3_train.csv', 'Monk/monks-3_test....            Class
# 25                                    Musk/clean1.csv        Column167
# 27                              Phishing/Phishing.csv            Class
# 28                  Room Occupancy/Room Occupancy.csv        Occupancy
# 29                           Sonar/sonar.all-data.csv            class
# 30                              Spambase/Spambase.csv            Class
# 31    Student/Students-Performance-MAT_processada.csv            Class
# 32                     titanic/titanic_processada.csv         Survived
# 33                                    Tokyo/Tokyo.csv            class
# 34                                twonorm/twonorm.csv            class
# 35                            Vertebral/column_2C.csv            class
# 37  Votes_Congressional/house-votes-84_processada.csv       Class Name
#
#                                               metrica     metrica_v2  \
# 1   {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 2   {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 3   {\n    "Quantidade de instâncias contrafactuai...  zero metricas
# 4   {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 5   {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 6   Input contains NaN, infinity or a value too la...           None
# 9   {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 10                                            memoria           None
# 11  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 13  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 14  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 15  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 16                array must not contain infs or NaNs           None
# 17                array must not contain infs or NaNs           None
# 18  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 19  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 20  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 21  {\n    "Quantidade de instâncias contrafactuai...           None
# 22  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 23  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 24  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 25                          fica dando erro de coluna           None
# 27  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 28  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 29  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 30  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 31                array must not contain infs or NaNs           None
# 32  Input contains NaN, infinity or a value too la...           None
# 33  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 34  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 35  {"Quantidade de inst\u00e2ncias contrafactuais...           None
# 37  {"Quantidade de inst\u00e2ncias contrafactuais...           None
#
#    gerou_resultado  tamanho        tipo
# 1                1    Média       Mista
# 2                1  Pequena    Numérica
# 3                1   Grande    Numérica
# 4                1  Pequena    Numérica
# 5                1   Grande    Numérica
# 6                1   Grande  Categórica
# 9                1  Pequena    Numérica
# 10               0    Média    Numérica
# 11               1    Média       Mista
# 13               1    Média       Mista
# 14               1    Média       Mista
# 15               1    Média    Numérica
# 16               1   Grande  Categórica
# 17               1   Grande    Numérica
# 18               1    Média    Numérica
# 19               1  Pequena    Numérica
# 20               1  Pequena  Categórica
# 21               1    Média    Numérica
# 22               1  Pequena  Categórica
# 23               1  Pequena  Categórica
# 24               1  Pequena  Categórica
# 25               1   Grande    Numérica
# 27               1   Grande  Categórica
# 28               1  Pequena    Numérica
# 29               1   Grande    Numérica
# 30               1   Grande    Numérica
# 31               1   Grande       Mista
# 32               1    Média       Mista
# 33               1   Grande    Numérica
# 34               1    Média    Numérica
# 35               1  Pequena    Numérica
# 37               1    Média  Categórica

# %%
import zipfile
import os

# Caminho do arquivo ZIP e o diretório de destino para extração
caminho_zip = 'datasets/results.zip'
diretorio_destino = 'datasets/'

# Garante que o diretório de destino existe
os.makedirs(diretorio_destino, exist_ok=True)

# Extrai todos os arquivos do ZIP para o diretório de destino
with zipfile.ZipFile(caminho_zip, 'r') as zip_ref:
    zip_ref.extractall(diretorio_destino)

print("Arquivos extraídos com sucesso!")
# Out:
# Arquivos extraídos com sucesso!

# %%
# import shutil
# import os

# # Caminho do diretório que você quer limpar e excluir
# diretorio = 'datasets/results'

# # Verifica se o diretório existe antes de tentar excluir
# if os.path.exists(diretorio):
#     # Remove todos os arquivos e subdiretórios dentro do diretório
#     shutil.rmtree(diretorio)
#     print(f"{diretorio} foi limpo e excluído com sucesso!")
# else:
#     print("O diretório não existe.")

# %%
import os

# Caminho da pasta que você quer listar os arquivos
caminho_pasta = 'datasets/results/rf'

# Lista todos os itens no diretório
arquivos = os.listdir(caminho_pasta)

# Filtra apenas os arquivos (ignorando subdiretórios)
# arquivos = [f for f in arquivos if os.path.isfile(os.path.join(caminho_pasta, f))]

print("Arquivos na pasta:")
for arquivo in arquivos:
    print(arquivo)
# Out:
# Arquivos na pasta:
# Australian.json
# Banknote.json
# Biodeg.json
# Breast Cancer Coimbra.json
# Breast Cancer Wisconsin.json
# Churn.json
# Diabetes.json
# EEg.json
# German.json
# Heart.json
# Heart_2.json
# HELOC.json
# Hill.json
# Horse colic.json
# Ionosfera.json
# KC2.json
# liver disorders_bupa.json
# mammographic_masses.json
# Mobile Price Classification.json
# Monk_1.json
# Monk_2.json
# Monk_3.json
# Musk.json
# Phishing.json
# Room Occupancy.json
# Sonar.json
# Spambase.json
# Student.json
# titanic.json
# Tokyo.json
# twonorm.json
# Vertebral_2C.json
# Votes_Congressional.json

# %%
import pandas as pd
import json
import os

# Definir o bucket e as pastas
path = 'datasets/results'
folders = ['rn', 'rf']

def list_files_in_folder(folder):
    # Lista todos os itens no diretório
    return os.listdir(caminho_pasta)

def load_json_from_s3(folder, key):
    with open(f"{path}/{folder}/{key}", 'r', encoding='utf-8') as arquivo:
        dados = json.load(arquivo)
    return dados
# Listar e carregar os JSONs
data = {}
for folder in folders:
    files = list_files_in_folder(folder)
    for file_key in files:
        base_name = file_key.replace('.json', '')  # Extrair o nome da base
        json_data = load_json_from_s3(folder, file_key)
        if base_name not in data:
            data[base_name] = {}
        if folder == 'rn':
            data[base_name]['Neural Network'] = json_data
        elif folder == 'rf':
            data[base_name]['Random Forest'] = json_data
        # data[base_name][folder] = json_data  # Adicionar o JSON à base

import pandas as pd

# Reformatar os dados para criar um DataFrame
data_reformatted = {}

# Iterar sobre as bases de dados e as pastas (rn, rf)
for base, folders_data in data.items():
    for folder, metrics in folders_data.items():
        for metric, value in metrics.items():
            # A chave do dicionário será uma tupla (base, folder)
            if metric not in data_reformatted:
                data_reformatted[metric] = {}
            data_reformatted[metric][(base, folder)] = value

# Criar o DataFrame com MultiIndex nas linhas (base de dados, pasta)
df = pd.DataFrame.from_dict(data_reformatted).unstack(level=1)

# Exibir o DataFrame
df.drop('Hill', inplace = True)
df
# Out:
#                             Quantidade de instâncias contrafactuais  \
#                                                      Neural Network
# Australian                                                      110
# Banknote                                                        110
# Biodeg                                                          110
# Breast Cancer Coimbra                                           110
# Breast Cancer Wisconsin                                         110
# Churn                                                           110
# Diabetes                                                        110
# EEg                                                             110
# German                                                          110
# HELOC                                                           110
# Heart                                                           110
# Heart_2                                                         110
# Horse colic                                                     110
# Ionosfera                                                       110
# KC2                                                             110
# Mobile Price Classification                                     110
# Monk_1                                                          110
# Monk_2                                                          110
# Monk_3                                                          110
# Musk                                                            110
# Phishing                                                        110
# Room Occupancy                                                  110
# Sonar                                                           110
# Spambase                                                        110
# Student                                                         110
# Tokyo                                                           110
# Vertebral_2C                                                    110
# Votes_Congressional                                             110
# liver disorders_bupa                                            110
# mammographic_masses                                             110
# titanic                                                         110
# twonorm                                                         110
#
#                                            \
#                             Random Forest
# Australian                            110
# Banknote                              110
# Biodeg                                110
# Breast Cancer Coimbra                 110
# Breast Cancer Wisconsin               110
# Churn                                 110
# Diabetes                              110
# EEg                                   110
# German                                110
# HELOC                                 110
# Heart                                 110
# Heart_2                               110
# Horse colic                           110
# Ionosfera                             110
# KC2                                   110
# Mobile Price Classification           110
# Monk_1                                110
# Monk_2                                110
# Monk_3                                110
# Musk                                  110
# Phishing                              110
# Room Occupancy                        110
# Sonar                                 110
# Spambase                              110
# Student                               110
# Tokyo                                 110
# Vertebral_2C                          110
# Votes_Congressional                   110
# liver disorders_bupa                  110
# mammographic_masses                   110
# titanic                               110
# twonorm                               110
#
#                             Quantidade de relações causais na base de dados  \
#                                                              Neural Network
# Australian                                                               30
# Banknote                                                                  6
# Biodeg                                                                  515
# Breast Cancer Coimbra                                                    15
# Breast Cancer Wisconsin                                                 351
# Churn                                                                   232
# Diabetes                                                                 16
# EEg                                                                      82
# German                                                                   69
# HELOC                                                                   195
# Heart                                                                    27
# Heart_2                                                                  33
# Horse colic                                                             110
# Ionosfera                                                               306
# KC2                                                                     184
# Mobile Price Classification                                               4
# Monk_1                                                                    0
# Monk_2                                                                    0
# Monk_3                                                                    0
# Musk                                                                   5067
# Phishing                                                                306
# Room Occupancy                                                           10
# Sonar                                                                   245
# Spambase                                                                370
# Student                                                                  99
# Tokyo                                                                   424
# Vertebral_2C                                                             11
# Votes_Congressional                                                      69
# liver disorders_bupa                                                     10
# mammographic_masses                                                       6
# titanic                                                                  64
# twonorm                                                                 190
#
#                                           Quantidade de atributos modificados  \
#                             Random Forest                      Neural Network
# Australian                             30                                   0
# Banknote                                6                                  43
# Biodeg                                515                                 113
# Breast Cancer Coimbra                  15                                  39
# Breast Cancer Wisconsin               351                                  48
# Churn                                 220                                 866
# Diabetes                               16                                  35
# EEg                                    82                                  41
# German                                 69                                 301
# HELOC                                 195                                 115
# Heart                                  27                                  58
# Heart_2                                33                                  65
# Horse colic                           103                                 163
# Ionosfera                             306                                  96
# KC2                                   184                                  31
# Mobile Price Classification             4                                 123
# Monk_1                                  0                                  52
# Monk_2                                  0                                  53
# Monk_3                                  0                                  42
# Musk                                 5067                                 503
# Phishing                              306                                1123
# Room Occupancy                         10                                  62
# Sonar                                 245                                 105
# Spambase                              370                                 226
# Student                                97                                 231
# Tokyo                                 424                                  71
# Vertebral_2C                           11                                  62
# Votes_Congressional                    68                                 452
# liver disorders_bupa                   10                                  45
# mammographic_masses                     6                                  57
# titanic                                64                                 316
# twonorm                               190                                 117
#
#                                            \
#                             Random Forest
# Australian                             41
# Banknote                               30
# Biodeg                                102
# Breast Cancer Coimbra                  64
# Breast Cancer Wisconsin               214
# Churn                                 357
# Diabetes                               62
# EEg                                    71
# German                                205
# HELOC                                  82
# Heart                                  78
# Heart_2                                55
# Horse colic                           287
# Ionosfera                             112
# KC2                                   169
# Mobile Price Classification            14
# Monk_1                                 42
# Monk_2                                 74
# Monk_3                                 48
# Musk                                 1223
# Phishing                             1020
# Room Occupancy                         45
# Sonar                                 749
# Spambase                              341
# Student                               238
# Tokyo                                 598
# Vertebral_2C                           43
# Votes_Congressional                   282
# liver disorders_bupa                   41
# mammographic_masses                    42
# titanic                               453
# twonorm                               147
#
#                             Quantidade de instâncias contrafactuais causais  \
#                                                              Neural Network
# Australian                                                                0
# Banknote                                                                 22
# Biodeg                                                                   14
# Breast Cancer Coimbra                                                    13
# Breast Cancer Wisconsin                                                   6
# Churn                                                                    45
# Diabetes                                                                 15
# EEg                                                                      17
# German                                                                   32
# HELOC                                                                    15
# Heart                                                                    21
# Heart_2                                                                  29
# Horse colic                                                              17
# Ionosfera                                                                15
# KC2                                                                      11
# Mobile Price Classification                                              55
# Monk_1                                                                   28
# Monk_2                                                                   22
# Monk_3                                                                   27
# Musk                                                                     20
# Phishing                                                                 55
# Room Occupancy                                                           21
# Sonar                                                                    25
# Spambase                                                                 22
# Student                                                                  58
# Tokyo                                                                    16
# Vertebral_2C                                                             20
# Votes_Congressional                                                      42
# liver disorders_bupa                                                     14
# mammographic_masses                                                      30
# titanic                                                                  73
# twonorm                                                                  20
#
#                                            \
#                             Random Forest
# Australian                             18
# Banknote                               16
# Biodeg                                 13
# Breast Cancer Coimbra                  19
# Breast Cancer Wisconsin                18
# Churn                                  15
# Diabetes                               20
# EEg                                    15
# German                                 27
# HELOC                                  17
# Heart                                  18
# Heart_2                                15
# Horse colic                            29
# Ionosfera                              11
# KC2                                    17
# Mobile Price Classification            12
# Monk_1                                 24
# Monk_2                                 31
# Monk_3                                 28
# Musk                                   14
# Phishing                               50
# Room Occupancy                         12
# Sonar                                  35
# Spambase                               18
# Student                                48
# Tokyo                                  21
# Vertebral_2C                           11
# Votes_Congressional                    30
# liver disorders_bupa                   11
# mammographic_masses                    23
# titanic                                69
# twonorm                                18
#
#                             Quantidade de relações causais analisadas  \
#                                                        Neural Network
# Australian                                                          0
# Banknote                                                           21
# Biodeg                                                            415
# Breast Cancer Coimbra                                              30
# Breast Cancer Wisconsin                                           132
# Churn                                                            4194
# Diabetes                                                           17
# EEg                                                                68
# German                                                            636
# HELOC                                                             402
# Heart                                                              34
# Heart_2                                                            26
# Horse colic                                                       272
# Ionosfera                                                         269
# KC2                                                                27
# Mobile Price Classification                                        14
# Monk_1                                                              0
# Monk_2                                                              0
# Monk_3                                                              0
# Musk                                                             4667
# Phishing                                                         9306
# Room Occupancy                                                     63
# Sonar                                                             104
# Spambase                                                          820
# Student                                                           168
# Tokyo                                                             106
# Vertebral_2C                                                       49
# Votes_Congressional                                              1497
# liver disorders_bupa                                               42
# mammographic_masses                                                20
# titanic                                                           336
# twonorm                                                           449
#
#                                            \
#                             Random Forest
# Australian                             20
# Banknote                               11
# Biodeg                                319
# Breast Cancer Coimbra                  62
# Breast Cancer Wisconsin              1047
# Churn                                1451
# Diabetes                               66
# EEg                                   161
# German                                396
# HELOC                                 180
# Heart                                  88
# Heart_2                                55
# Horse colic                           512
# Ionosfera                             401
# KC2                                   760
# Mobile Price Classification             0
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Musk                                21951
# Phishing                             8299
# Room Occupancy                         63
# Sonar                                2183
# Spambase                             1582
# Student                               183
# Tokyo                                4813
# Vertebral_2C                           36
# Votes_Congressional                   849
# liver disorders_bupa                   37
# mammographic_masses                    15
# titanic                               580
# twonorm                               675
#
#                             Quantidade de relações causais satisfeitas  \
#                                                         Neural Network
# Australian                                                           0
# Banknote                                                            14
# Biodeg                                                             250
# Breast Cancer Coimbra                                               19
# Breast Cancer Wisconsin                                             77
# Churn                                                             2545
# Diabetes                                                             9
# EEg                                                                 38
# German                                                             473
# HELOC                                                              220
# Heart                                                               25
# Heart_2                                                             19
# Horse colic                                                        158
# Ionosfera                                                          194
# KC2                                                                 22
# Mobile Price Classification                                         14
# Monk_1                                                               0
# Monk_2                                                               0
# Monk_3                                                               0
# Musk                                                              2578
# Phishing                                                          5635
# Room Occupancy                                                      40
# Sonar                                                               98
# Spambase                                                           643
# Student                                                            115
# Tokyo                                                               72
# Vertebral_2C                                                        27
# Votes_Congressional                                               1279
# liver disorders_bupa                                                24
# mammographic_masses                                                 11
# titanic                                                            222
# twonorm                                                            349
#
#                                            \
#                             Random Forest
# Australian                             17
# Banknote                                8
# Biodeg                                178
# Breast Cancer Coimbra                  37
# Breast Cancer Wisconsin               572
# Churn                                 854
# Diabetes                               40
# EEg                                   109
# German                                284
# HELOC                                 115
# Heart                                  67
# Heart_2                                48
# Horse colic                           272
# Ionosfera                             284
# KC2                                   444
# Mobile Price Classification             0
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Musk                                11498
# Phishing                             5087
# Room Occupancy                         42
# Sonar                                1842
# Spambase                             1336
# Student                               118
# Tokyo                                2667
# Vertebral_2C                           21
# Votes_Congressional                   647
# liver disorders_bupa                   26
# mammographic_masses                    11
# titanic                               407
# twonorm                               635
#
#                             Quantidade de instâncias contrafactuais com um único atributo modificado  \
#                                                                                       Neural Network
# Australian                                                                   0
# Banknote                                                                    10
# Biodeg                                                                       0
# Breast Cancer Coimbra                                                        3
# Breast Cancer Wisconsin                                                      0
# Churn                                                                        7
# Diabetes                                                                     8
# EEg                                                                         10
# German                                                                       0
# HELOC                                                                        3
# Heart                                                                       13
# Heart_2                                                                     17
# Horse colic                                                                  0
# Ionosfera                                                                    2
# KC2                                                                          3
# Mobile Price Classification                                                 41
# Monk_1                                                                      28
# Monk_2                                                                      22
# Monk_3                                                                      27
# Musk                                                                         1
# Phishing                                                                     1
# Room Occupancy                                                               3
# Sonar                                                                        9
# Spambase                                                                     1
# Student                                                                     26
# Tokyo                                                                        0
# Vertebral_2C                                                                 4
# Votes_Congressional                                                          0
# liver disorders_bupa                                                         2
# mammographic_masses                                                         22
# titanic                                                                     14
# twonorm                                                                      1
#
#                                           Tempo de execução
#                             Random Forest    Neural Network Random Forest
# Australian                             10        662.409290    170.314212
# Banknote                                8        141.178057    140.949971
# Biodeg                                  0       1205.567920    981.805070
# Breast Cancer Coimbra                   2        145.567600    143.835234
# Breast Cancer Wisconsin                 0        535.944079    833.401842
# Churn                                   0        441.840517    422.599502
# Diabetes                                8        162.025412    158.994113
# EEg                                     1        263.851723    287.367322
# German                                  2        253.193645    223.357106
# HELOC                                   0        517.143132    454.813778
# Heart                                   5        168.597033    173.003850
# Heart_2                                 3        162.596136    152.121104
# Horse colic                             0        254.491596    229.007077
# Ionosfera                               0        794.978922    830.841133
# KC2                                     1        354.907701    607.911204
# Mobile Price Classification            12        144.199227    150.504338
# Monk_1                                 24          9.087778      6.621997
# Monk_2                                 31          9.302449      6.820625
# Monk_3                                 28          9.749496      6.913668
# Musk                                    0      18336.578551  27134.813527
# Phishing                                0        441.759608    452.906020
# Room Occupancy                          0        153.161432    146.928882
# Sonar                                   0        390.911860    579.041518
# Spambase                                0        819.483918   1116.299825
# Student                                 9        203.134795    186.345053
# Tokyo                                   0        937.520761   1261.046824
# Vertebral_2C                            2        140.843718    144.343818
# Votes_Congressional                     0         57.573072     51.140794
# liver disorders_bupa                    3        135.812516    136.577896
# mammographic_masses                    17        104.350760    101.468797
# titanic                                 9         87.254891     90.875795
# twonorm                                 2        576.958079    586.009112

# %%
size_order = ['Banknote',
 'mammographic_masses',
 'Room Occupancy',
 'liver disorders_bupa',
 'Monk_1',
 'Monk_2',
 'Monk_3',
 'Vertebral_2C',
 'Diabetes',
 'Breast Cancer Coimbra',
 'Heart',
 'Heart_2',
 'EEg',
 'Australian',
 'Votes_Congressional',
 'German',
 'Mobile Price Classification',
 'twonorm',
 'KC2',
 'HELOC',
 'titanic',
 'Phishing',
 'Breast Cancer Wisconsin',
 'Ionosfera',
 'Horse colic',
 'Churn',
 'Biodeg',
 'Student',
 'Tokyo',
 'Spambase',
 'Sonar',
 'Musk']

size_list = [('Banknote', 5),
 ('mammographic_masses', 6),
 ('Room Occupancy', 6),
 ('liver disorders_bupa', 7),
 ('Monk_1', 7),
 ('Monk_2', 7),
 ('Monk_3', 7),
 ('Vertebral_2C', 7),
 ('Diabetes', 9),
 ('Breast Cancer Coimbra', 10),
 ('Heart', 14),
 ('Heart_2', 14),
 ('EEg', 15),
 ('Australian', 16),
 ('Votes_Congressional', 17),
 ('German', 21),
 ('Mobile Price Classification', 21),
 ('twonorm', 21),
 ('KC2', 22),
 ('HELOC', 24),
 ('titanic', 27),
 ('Phishing', 31),
 ('Breast Cancer Wisconsin', 32),
 ('Ionosfera', 35),
 ('Horse colic', 37),
 ('Churn', 41),
 ('Biodeg', 42),
 ('Student', 44),
 ('Tokyo', 45),
 ('Spambase', 58),
 ('Sonar', 61),
 ('Musk', 165)]

# %%
df = df.reindex(size_order)
df
# Out:
#                             Quantidade de instâncias contrafactuais  \
#                                                      Neural Network
# Banknote                                                        110
# mammographic_masses                                             110
# Room Occupancy                                                  110
# liver disorders_bupa                                            110
# Monk_1                                                          110
# Monk_2                                                          110
# Monk_3                                                          110
# Vertebral_2C                                                    110
# Diabetes                                                        110
# Breast Cancer Coimbra                                           110
# Heart                                                           110
# Heart_2                                                         110
# EEg                                                             110
# Australian                                                      110
# Votes_Congressional                                             110
# German                                                          110
# Mobile Price Classification                                     110
# twonorm                                                         110
# KC2                                                             110
# HELOC                                                           110
# titanic                                                         110
# Phishing                                                        110
# Breast Cancer Wisconsin                                         110
# Ionosfera                                                       110
# Horse colic                                                     110
# Churn                                                           110
# Biodeg                                                          110
# Student                                                         110
# Tokyo                                                           110
# Spambase                                                        110
# Sonar                                                           110
# Musk                                                            110
#
#                                            \
#                             Random Forest
# Banknote                              110
# mammographic_masses                   110
# Room Occupancy                        110
# liver disorders_bupa                  110
# Monk_1                                110
# Monk_2                                110
# Monk_3                                110
# Vertebral_2C                          110
# Diabetes                              110
# Breast Cancer Coimbra                 110
# Heart                                 110
# Heart_2                               110
# EEg                                   110
# Australian                            110
# Votes_Congressional                   110
# German                                110
# Mobile Price Classification           110
# twonorm                               110
# KC2                                   110
# HELOC                                 110
# titanic                               110
# Phishing                              110
# Breast Cancer Wisconsin               110
# Ionosfera                             110
# Horse colic                           110
# Churn                                 110
# Biodeg                                110
# Student                               110
# Tokyo                                 110
# Spambase                              110
# Sonar                                 110
# Musk                                  110
#
#                             Quantidade de relações causais na base de dados  \
#                                                              Neural Network
# Banknote                                                                  6
# mammographic_masses                                                       6
# Room Occupancy                                                           10
# liver disorders_bupa                                                     10
# Monk_1                                                                    0
# Monk_2                                                                    0
# Monk_3                                                                    0
# Vertebral_2C                                                             11
# Diabetes                                                                 16
# Breast Cancer Coimbra                                                    15
# Heart                                                                    27
# Heart_2                                                                  33
# EEg                                                                      82
# Australian                                                               30
# Votes_Congressional                                                      69
# German                                                                   69
# Mobile Price Classification                                               4
# twonorm                                                                 190
# KC2                                                                     184
# HELOC                                                                   195
# titanic                                                                  64
# Phishing                                                                306
# Breast Cancer Wisconsin                                                 351
# Ionosfera                                                               306
# Horse colic                                                             110
# Churn                                                                   232
# Biodeg                                                                  515
# Student                                                                  99
# Tokyo                                                                   424
# Spambase                                                                370
# Sonar                                                                   245
# Musk                                                                   5067
#
#                                           Quantidade de atributos modificados  \
#                             Random Forest                      Neural Network
# Banknote                                6                                  43
# mammographic_masses                     6                                  57
# Room Occupancy                         10                                  62
# liver disorders_bupa                   10                                  45
# Monk_1                                  0                                  52
# Monk_2                                  0                                  53
# Monk_3                                  0                                  42
# Vertebral_2C                           11                                  62
# Diabetes                               16                                  35
# Breast Cancer Coimbra                  15                                  39
# Heart                                  27                                  58
# Heart_2                                33                                  65
# EEg                                    82                                  41
# Australian                             30                                   0
# Votes_Congressional                    68                                 452
# German                                 69                                 301
# Mobile Price Classification             4                                 123
# twonorm                               190                                 117
# KC2                                   184                                  31
# HELOC                                 195                                 115
# titanic                                64                                 316
# Phishing                              306                                1123
# Breast Cancer Wisconsin               351                                  48
# Ionosfera                             306                                  96
# Horse colic                           103                                 163
# Churn                                 220                                 866
# Biodeg                                515                                 113
# Student                                97                                 231
# Tokyo                                 424                                  71
# Spambase                              370                                 226
# Sonar                                 245                                 105
# Musk                                 5067                                 503
#
#                                            \
#                             Random Forest
# Banknote                               30
# mammographic_masses                    42
# Room Occupancy                         45
# liver disorders_bupa                   41
# Monk_1                                 42
# Monk_2                                 74
# Monk_3                                 48
# Vertebral_2C                           43
# Diabetes                               62
# Breast Cancer Coimbra                  64
# Heart                                  78
# Heart_2                                55
# EEg                                    71
# Australian                             41
# Votes_Congressional                   282
# German                                205
# Mobile Price Classification            14
# twonorm                               147
# KC2                                   169
# HELOC                                  82
# titanic                               453
# Phishing                             1020
# Breast Cancer Wisconsin               214
# Ionosfera                             112
# Horse colic                           287
# Churn                                 357
# Biodeg                                102
# Student                               238
# Tokyo                                 598
# Spambase                              341
# Sonar                                 749
# Musk                                 1223
#
#                             Quantidade de instâncias contrafactuais causais  \
#                                                              Neural Network
# Banknote                                                                 22
# mammographic_masses                                                      30
# Room Occupancy                                                           21
# liver disorders_bupa                                                     14
# Monk_1                                                                   28
# Monk_2                                                                   22
# Monk_3                                                                   27
# Vertebral_2C                                                             20
# Diabetes                                                                 15
# Breast Cancer Coimbra                                                    13
# Heart                                                                    21
# Heart_2                                                                  29
# EEg                                                                      17
# Australian                                                                0
# Votes_Congressional                                                      42
# German                                                                   32
# Mobile Price Classification                                              55
# twonorm                                                                  20
# KC2                                                                      11
# HELOC                                                                    15
# titanic                                                                  73
# Phishing                                                                 55
# Breast Cancer Wisconsin                                                   6
# Ionosfera                                                                15
# Horse colic                                                              17
# Churn                                                                    45
# Biodeg                                                                   14
# Student                                                                  58
# Tokyo                                                                    16
# Spambase                                                                 22
# Sonar                                                                    25
# Musk                                                                     20
#
#                                            \
#                             Random Forest
# Banknote                               16
# mammographic_masses                    23
# Room Occupancy                         12
# liver disorders_bupa                   11
# Monk_1                                 24
# Monk_2                                 31
# Monk_3                                 28
# Vertebral_2C                           11
# Diabetes                               20
# Breast Cancer Coimbra                  19
# Heart                                  18
# Heart_2                                15
# EEg                                    15
# Australian                             18
# Votes_Congressional                    30
# German                                 27
# Mobile Price Classification            12
# twonorm                                18
# KC2                                    17
# HELOC                                  17
# titanic                                69
# Phishing                               50
# Breast Cancer Wisconsin                18
# Ionosfera                              11
# Horse colic                            29
# Churn                                  15
# Biodeg                                 13
# Student                                48
# Tokyo                                  21
# Spambase                               18
# Sonar                                  35
# Musk                                   14
#
#                             Quantidade de relações causais analisadas  \
#                                                        Neural Network
# Banknote                                                           21
# mammographic_masses                                                20
# Room Occupancy                                                     63
# liver disorders_bupa                                               42
# Monk_1                                                              0
# Monk_2                                                              0
# Monk_3                                                              0
# Vertebral_2C                                                       49
# Diabetes                                                           17
# Breast Cancer Coimbra                                              30
# Heart                                                              34
# Heart_2                                                            26
# EEg                                                                68
# Australian                                                          0
# Votes_Congressional                                              1497
# German                                                            636
# Mobile Price Classification                                        14
# twonorm                                                           449
# KC2                                                                27
# HELOC                                                             402
# titanic                                                           336
# Phishing                                                         9306
# Breast Cancer Wisconsin                                           132
# Ionosfera                                                         269
# Horse colic                                                       272
# Churn                                                            4194
# Biodeg                                                            415
# Student                                                           168
# Tokyo                                                             106
# Spambase                                                          820
# Sonar                                                             104
# Musk                                                             4667
#
#                                            \
#                             Random Forest
# Banknote                               11
# mammographic_masses                    15
# Room Occupancy                         63
# liver disorders_bupa                   37
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           36
# Diabetes                               66
# Breast Cancer Coimbra                  62
# Heart                                  88
# Heart_2                                55
# EEg                                   161
# Australian                             20
# Votes_Congressional                   849
# German                                396
# Mobile Price Classification             0
# twonorm                               675
# KC2                                   760
# HELOC                                 180
# titanic                               580
# Phishing                             8299
# Breast Cancer Wisconsin              1047
# Ionosfera                             401
# Horse colic                           512
# Churn                                1451
# Biodeg                                319
# Student                               183
# Tokyo                                4813
# Spambase                             1582
# Sonar                                2183
# Musk                                21951
#
#                             Quantidade de relações causais satisfeitas  \
#                                                         Neural Network
# Banknote                                                            14
# mammographic_masses                                                 11
# Room Occupancy                                                      40
# liver disorders_bupa                                                24
# Monk_1                                                               0
# Monk_2                                                               0
# Monk_3                                                               0
# Vertebral_2C                                                        27
# Diabetes                                                             9
# Breast Cancer Coimbra                                               19
# Heart                                                               25
# Heart_2                                                             19
# EEg                                                                 38
# Australian                                                           0
# Votes_Congressional                                               1279
# German                                                             473
# Mobile Price Classification                                         14
# twonorm                                                            349
# KC2                                                                 22
# HELOC                                                              220
# titanic                                                            222
# Phishing                                                          5635
# Breast Cancer Wisconsin                                             77
# Ionosfera                                                          194
# Horse colic                                                        158
# Churn                                                             2545
# Biodeg                                                             250
# Student                                                            115
# Tokyo                                                               72
# Spambase                                                           643
# Sonar                                                               98
# Musk                                                              2578
#
#                                            \
#                             Random Forest
# Banknote                                8
# mammographic_masses                    11
# Room Occupancy                         42
# liver disorders_bupa                   26
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           21
# Diabetes                               40
# Breast Cancer Coimbra                  37
# Heart                                  67
# Heart_2                                48
# EEg                                   109
# Australian                             17
# Votes_Congressional                   647
# German                                284
# Mobile Price Classification             0
# twonorm                               635
# KC2                                   444
# HELOC                                 115
# titanic                               407
# Phishing                             5087
# Breast Cancer Wisconsin               572
# Ionosfera                             284
# Horse colic                           272
# Churn                                 854
# Biodeg                                178
# Student                               118
# Tokyo                                2667
# Spambase                             1336
# Sonar                                1842
# Musk                                11498
#
#                             Quantidade de instâncias contrafactuais com um único atributo modificado  \
#                                                                                       Neural Network
# Banknote                                                                    10
# mammographic_masses                                                         22
# Room Occupancy                                                               3
# liver disorders_bupa                                                         2
# Monk_1                                                                      28
# Monk_2                                                                      22
# Monk_3                                                                      27
# Vertebral_2C                                                                 4
# Diabetes                                                                     8
# Breast Cancer Coimbra                                                        3
# Heart                                                                       13
# Heart_2                                                                     17
# EEg                                                                         10
# Australian                                                                   0
# Votes_Congressional                                                          0
# German                                                                       0
# Mobile Price Classification                                                 41
# twonorm                                                                      1
# KC2                                                                          3
# HELOC                                                                        3
# titanic                                                                     14
# Phishing                                                                     1
# Breast Cancer Wisconsin                                                      0
# Ionosfera                                                                    2
# Horse colic                                                                  0
# Churn                                                                        7
# Biodeg                                                                       0
# Student                                                                     26
# Tokyo                                                                        0
# Spambase                                                                     1
# Sonar                                                                        9
# Musk                                                                         1
#
#                                           Tempo de execução
#                             Random Forest    Neural Network Random Forest
# Banknote                                8        141.178057    140.949971
# mammographic_masses                    17        104.350760    101.468797
# Room Occupancy                          0        153.161432    146.928882
# liver disorders_bupa                    3        135.812516    136.577896
# Monk_1                                 24          9.087778      6.621997
# Monk_2                                 31          9.302449      6.820625
# Monk_3                                 28          9.749496      6.913668
# Vertebral_2C                            2        140.843718    144.343818
# Diabetes                                8        162.025412    158.994113
# Breast Cancer Coimbra                   2        145.567600    143.835234
# Heart                                   5        168.597033    173.003850
# Heart_2                                 3        162.596136    152.121104
# EEg                                     1        263.851723    287.367322
# Australian                             10        662.409290    170.314212
# Votes_Congressional                     0         57.573072     51.140794
# German                                  2        253.193645    223.357106
# Mobile Price Classification            12        144.199227    150.504338
# twonorm                                 2        576.958079    586.009112
# KC2                                     1        354.907701    607.911204
# HELOC                                   0        517.143132    454.813778
# titanic                                 9         87.254891     90.875795
# Phishing                                0        441.759608    452.906020
# Breast Cancer Wisconsin                 0        535.944079    833.401842
# Ionosfera                               0        794.978922    830.841133
# Horse colic                             0        254.491596    229.007077
# Churn                                   0        441.840517    422.599502
# Biodeg                                  0       1205.567920    981.805070
# Student                                 9        203.134795    186.345053
# Tokyo                                   0        937.520761   1261.046824
# Spambase                                0        819.483918   1116.299825
# Sonar                                   0        390.911860    579.041518
# Musk                                    0      18336.578551  27134.813527

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotar heatmaps para cada métrica
for metric in df.columns.levels[0]:  # Iterar sobre as métricas
    plt.figure(figsize=(8, 10))
    sns.heatmap(df[metric], annot=True, cmap="YlGnBu", cbar_kws={'label': metric}, fmt="g")

    plt.title(f"{metric}")
    plt.xlabel("Black Box")
    plt.ylabel("Base de Dados")
    plt.show()

# %%
df.drop('Musk', inplace = True)

# %%
dataset_mapping = {
    'Banknote': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'mammographic_masses': {'Tamanho': 'Pequena', 'Tipo': 'Categórica'},
    'Room Occupancy': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'liver disorders_bupa': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'Monk_1': {'Tamanho': 'Pequena', 'Tipo': 'Categórica'},
    'Monk_2': {'Tamanho': 'Pequena', 'Tipo': 'Categórica'},
    'Monk_3': {'Tamanho': 'Pequena', 'Tipo': 'Categórica'},
    'Vertebral_2C': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'Diabetes': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'Breast Cancer Coimbra': {'Tamanho': 'Pequena', 'Tipo': 'Numérica'},
    'Heart': {'Tamanho': 'Média', 'Tipo': 'Mista'},
    'Heart_2': {'Tamanho': 'Média', 'Tipo': 'Mista'},
    'EEg': {'Tamanho': 'Média', 'Tipo': 'Numérica'},
    'Australian': {'Tamanho': 'Média', 'Tipo': 'Mista'},
    'Votes_Congressional': {'Tamanho': 'Média', 'Tipo': 'Categórica'},
    'German': {'Tamanho': 'Média', 'Tipo': 'Mista'},
    'Mobile Price Classification': {'Tamanho': 'Média', 'Tipo': 'Numérica'},
    'twonorm': {'Tamanho': 'Média', 'Tipo': 'Numérica'},
    'KC2': {'Tamanho': 'Média', 'Tipo': 'Numérica'},
    'HELOC': {'Tamanho': 'Média', 'Tipo': 'Numérica'},
    'titanic': {'Tamanho': 'Média', 'Tipo': 'Mista'},
    'Phishing': {'Tamanho': 'Grande', 'Tipo': 'Categórica'},
    'Breast Cancer Wisconsin': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Ionosfera': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Horse colic': {'Tamanho': 'Grande', 'Tipo': 'Categórica'},
    'Churn': {'Tamanho': 'Grande', 'Tipo': 'Categórica'},
    'Biodeg': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Student': {'Tamanho': 'Grande', 'Tipo': 'Mista'},
    'Tokyo': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Spambase': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Sonar': {'Tamanho': 'Grande', 'Tipo': 'Numérica'},
    'Musk': {'Tamanho': 'Grande', 'Tipo': 'Numérica'}
}

pequeno = [idx for idx, item in dataset_mapping.items() if item['Tamanho'] == "Pequena"]
medio = [idx for idx, item in dataset_mapping.items() if item['Tamanho'] == "Média"]
grande = [idx for idx, item in dataset_mapping.items() if item['Tamanho'] == "Grande"]

numerica = [idx for idx, item in dataset_mapping.items() if item['Tipo'] == "Numérica"]
categorica = [idx for idx, item in dataset_mapping.items() if item['Tipo'] == "Categórica"]
mista = [idx for idx, item in dataset_mapping.items() if item['Tipo'] == "Mista"]

# %%
translated_metrics = {
    "Quantidade de instâncias contrafactuais": "Number of counterfactual instances",
    "Quantidade de relações causais na base de dados": "Number of causal relationships in the database",
    "Quantidade de atributos modificados": "Number of modified attributes",
    "Quantidade de instâncias contrafactuais causais": "Number of causal counterfactual instances",
    "Quantidade de relações causais analisadas": "Number of analyzed causal relationships",
    "Quantidade de relações causais satisfeitas": "Number of satisfied causal relationships",
    "Quantidade de instâncias contrafactuais com um único atributo modificado": "Number of counterfactual instances with a single modified attribute",
    "Tempo de execução": "Execution time",
    "Proporção entre relações satisfeitas/analisadas": "Proportion of satisfied/analyzed relationships" 
}

# %%
coluna_nova = "Proporção entre relações satisfeitas/analisadas"
coluna_x = "Quantidade de relações causais satisfeitas"
coluna_y = "Quantidade de relações causais analisadas"

for metric in df.columns.levels[1]:
    df[(coluna_nova, metric)] = df[(coluna_x, metric)] / df[(coluna_y, metric)] * 100

# Reorganiza as colunas para manter a hierarquia
df = df.fillna(100)
df
# Out:
#                             Quantidade de instâncias contrafactuais  \
#                                                      Neural Network
# Banknote                                                        110
# mammographic_masses                                             110
# Room Occupancy                                                  110
# liver disorders_bupa                                            110
# Monk_1                                                          110
# Monk_2                                                          110
# Monk_3                                                          110
# Vertebral_2C                                                    110
# Diabetes                                                        110
# Breast Cancer Coimbra                                           110
# Heart                                                           110
# Heart_2                                                         110
# EEg                                                             110
# Australian                                                      110
# Votes_Congressional                                             110
# German                                                          110
# Mobile Price Classification                                     110
# twonorm                                                         110
# KC2                                                             110
# HELOC                                                           110
# titanic                                                         110
# Phishing                                                        110
# Breast Cancer Wisconsin                                         110
# Ionosfera                                                       110
# Horse colic                                                     110
# Churn                                                           110
# Biodeg                                                          110
# Student                                                         110
# Tokyo                                                           110
# Spambase                                                        110
# Sonar                                                           110
#
#                                            \
#                             Random Forest
# Banknote                              110
# mammographic_masses                   110
# Room Occupancy                        110
# liver disorders_bupa                  110
# Monk_1                                110
# Monk_2                                110
# Monk_3                                110
# Vertebral_2C                          110
# Diabetes                              110
# Breast Cancer Coimbra                 110
# Heart                                 110
# Heart_2                               110
# EEg                                   110
# Australian                            110
# Votes_Congressional                   110
# German                                110
# Mobile Price Classification           110
# twonorm                               110
# KC2                                   110
# HELOC                                 110
# titanic                               110
# Phishing                              110
# Breast Cancer Wisconsin               110
# Ionosfera                             110
# Horse colic                           110
# Churn                                 110
# Biodeg                                110
# Student                               110
# Tokyo                                 110
# Spambase                              110
# Sonar                                 110
#
#                             Quantidade de relações causais na base de dados  \
#                                                              Neural Network
# Banknote                                                                  6
# mammographic_masses                                                       6
# Room Occupancy                                                           10
# liver disorders_bupa                                                     10
# Monk_1                                                                    0
# Monk_2                                                                    0
# Monk_3                                                                    0
# Vertebral_2C                                                             11
# Diabetes                                                                 16
# Breast Cancer Coimbra                                                    15
# Heart                                                                    27
# Heart_2                                                                  33
# EEg                                                                      82
# Australian                                                               30
# Votes_Congressional                                                      69
# German                                                                   69
# Mobile Price Classification                                               4
# twonorm                                                                 190
# KC2                                                                     184
# HELOC                                                                   195
# titanic                                                                  64
# Phishing                                                                306
# Breast Cancer Wisconsin                                                 351
# Ionosfera                                                               306
# Horse colic                                                             110
# Churn                                                                   232
# Biodeg                                                                  515
# Student                                                                  99
# Tokyo                                                                   424
# Spambase                                                                370
# Sonar                                                                   245
#
#                                           Quantidade de atributos modificados  \
#                             Random Forest                      Neural Network
# Banknote                                6                                  43
# mammographic_masses                     6                                  57
# Room Occupancy                         10                                  62
# liver disorders_bupa                   10                                  45
# Monk_1                                  0                                  52
# Monk_2                                  0                                  53
# Monk_3                                  0                                  42
# Vertebral_2C                           11                                  62
# Diabetes                               16                                  35
# Breast Cancer Coimbra                  15                                  39
# Heart                                  27                                  58
# Heart_2                                33                                  65
# EEg                                    82                                  41
# Australian                             30                                   0
# Votes_Congressional                    68                                 452
# German                                 69                                 301
# Mobile Price Classification             4                                 123
# twonorm                               190                                 117
# KC2                                   184                                  31
# HELOC                                 195                                 115
# titanic                                64                                 316
# Phishing                              306                                1123
# Breast Cancer Wisconsin               351                                  48
# Ionosfera                             306                                  96
# Horse colic                           103                                 163
# Churn                                 220                                 866
# Biodeg                                515                                 113
# Student                                97                                 231
# Tokyo                                 424                                  71
# Spambase                              370                                 226
# Sonar                                 245                                 105
#
#                                            \
#                             Random Forest
# Banknote                               30
# mammographic_masses                    42
# Room Occupancy                         45
# liver disorders_bupa                   41
# Monk_1                                 42
# Monk_2                                 74
# Monk_3                                 48
# Vertebral_2C                           43
# Diabetes                               62
# Breast Cancer Coimbra                  64
# Heart                                  78
# Heart_2                                55
# EEg                                    71
# Australian                             41
# Votes_Congressional                   282
# German                                205
# Mobile Price Classification            14
# twonorm                               147
# KC2                                   169
# HELOC                                  82
# titanic                               453
# Phishing                             1020
# Breast Cancer Wisconsin               214
# Ionosfera                             112
# Horse colic                           287
# Churn                                 357
# Biodeg                                102
# Student                               238
# Tokyo                                 598
# Spambase                              341
# Sonar                                 749
#
#                             Quantidade de instâncias contrafactuais causais  \
#                                                              Neural Network
# Banknote                                                                 22
# mammographic_masses                                                      30
# Room Occupancy                                                           21
# liver disorders_bupa                                                     14
# Monk_1                                                                   28
# Monk_2                                                                   22
# Monk_3                                                                   27
# Vertebral_2C                                                             20
# Diabetes                                                                 15
# Breast Cancer Coimbra                                                    13
# Heart                                                                    21
# Heart_2                                                                  29
# EEg                                                                      17
# Australian                                                                0
# Votes_Congressional                                                      42
# German                                                                   32
# Mobile Price Classification                                              55
# twonorm                                                                  20
# KC2                                                                      11
# HELOC                                                                    15
# titanic                                                                  73
# Phishing                                                                 55
# Breast Cancer Wisconsin                                                   6
# Ionosfera                                                                15
# Horse colic                                                              17
# Churn                                                                    45
# Biodeg                                                                   14
# Student                                                                  58
# Tokyo                                                                    16
# Spambase                                                                 22
# Sonar                                                                    25
#
#                                            \
#                             Random Forest
# Banknote                               16
# mammographic_masses                    23
# Room Occupancy                         12
# liver disorders_bupa                   11
# Monk_1                                 24
# Monk_2                                 31
# Monk_3                                 28
# Vertebral_2C                           11
# Diabetes                               20
# Breast Cancer Coimbra                  19
# Heart                                  18
# Heart_2                                15
# EEg                                    15
# Australian                             18
# Votes_Congressional                    30
# German                                 27
# Mobile Price Classification            12
# twonorm                                18
# KC2                                    17
# HELOC                                  17
# titanic                                69
# Phishing                               50
# Breast Cancer Wisconsin                18
# Ionosfera                              11
# Horse colic                            29
# Churn                                  15
# Biodeg                                 13
# Student                                48
# Tokyo                                  21
# Spambase                               18
# Sonar                                  35
#
#                             Quantidade de relações causais analisadas  \
#                                                        Neural Network
# Banknote                                                           21
# mammographic_masses                                                20
# Room Occupancy                                                     63
# liver disorders_bupa                                               42
# Monk_1                                                              0
# Monk_2                                                              0
# Monk_3                                                              0
# Vertebral_2C                                                       49
# Diabetes                                                           17
# Breast Cancer Coimbra                                              30
# Heart                                                              34
# Heart_2                                                            26
# EEg                                                                68
# Australian                                                          0
# Votes_Congressional                                              1497
# German                                                            636
# Mobile Price Classification                                        14
# twonorm                                                           449
# KC2                                                                27
# HELOC                                                             402
# titanic                                                           336
# Phishing                                                         9306
# Breast Cancer Wisconsin                                           132
# Ionosfera                                                         269
# Horse colic                                                       272
# Churn                                                            4194
# Biodeg                                                            415
# Student                                                           168
# Tokyo                                                             106
# Spambase                                                          820
# Sonar                                                             104
#
#                                            \
#                             Random Forest
# Banknote                               11
# mammographic_masses                    15
# Room Occupancy                         63
# liver disorders_bupa                   37
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           36
# Diabetes                               66
# Breast Cancer Coimbra                  62
# Heart                                  88
# Heart_2                                55
# EEg                                   161
# Australian                             20
# Votes_Congressional                   849
# German                                396
# Mobile Price Classification             0
# twonorm                               675
# KC2                                   760
# HELOC                                 180
# titanic                               580
# Phishing                             8299
# Breast Cancer Wisconsin              1047
# Ionosfera                             401
# Horse colic                           512
# Churn                                1451
# Biodeg                                319
# Student                               183
# Tokyo                                4813
# Spambase                             1582
# Sonar                                2183
#
#                             Quantidade de relações causais satisfeitas  \
#                                                         Neural Network
# Banknote                                                            14
# mammographic_masses                                                 11
# Room Occupancy                                                      40
# liver disorders_bupa                                                24
# Monk_1                                                               0
# Monk_2                                                               0
# Monk_3                                                               0
# Vertebral_2C                                                        27
# Diabetes                                                             9
# Breast Cancer Coimbra                                               19
# Heart                                                               25
# Heart_2                                                             19
# EEg                                                                 38
# Australian                                                           0
# Votes_Congressional                                               1279
# German                                                             473
# Mobile Price Classification                                         14
# twonorm                                                            349
# KC2                                                                 22
# HELOC                                                              220
# titanic                                                            222
# Phishing                                                          5635
# Breast Cancer Wisconsin                                             77
# Ionosfera                                                          194
# Horse colic                                                        158
# Churn                                                             2545
# Biodeg                                                             250
# Student                                                            115
# Tokyo                                                               72
# Spambase                                                           643
# Sonar                                                               98
#
#                                            \
#                             Random Forest
# Banknote                                8
# mammographic_masses                    11
# Room Occupancy                         42
# liver disorders_bupa                   26
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           21
# Diabetes                               40
# Breast Cancer Coimbra                  37
# Heart                                  67
# Heart_2                                48
# EEg                                   109
# Australian                             17
# Votes_Congressional                   647
# German                                284
# Mobile Price Classification             0
# twonorm                               635
# KC2                                   444
# HELOC                                 115
# titanic                               407
# Phishing                             5087
# Breast Cancer Wisconsin               572
# Ionosfera                             284
# Horse colic                           272
# Churn                                 854
# Biodeg                                178
# Student                               118
# Tokyo                                2667
# Spambase                             1336
# Sonar                                1842
#
#                             Quantidade de instâncias contrafactuais com um único atributo modificado  \
#                                                                                       Neural Network
# Banknote                                                                    10
# mammographic_masses                                                         22
# Room Occupancy                                                               3
# liver disorders_bupa                                                         2
# Monk_1                                                                      28
# Monk_2                                                                      22
# Monk_3                                                                      27
# Vertebral_2C                                                                 4
# Diabetes                                                                     8
# Breast Cancer Coimbra                                                        3
# Heart                                                                       13
# Heart_2                                                                     17
# EEg                                                                         10
# Australian                                                                   0
# Votes_Congressional                                                          0
# German                                                                       0
# Mobile Price Classification                                                 41
# twonorm                                                                      1
# KC2                                                                          3
# HELOC                                                                        3
# titanic                                                                     14
# Phishing                                                                     1
# Breast Cancer Wisconsin                                                      0
# Ionosfera                                                                    2
# Horse colic                                                                  0
# Churn                                                                        7
# Biodeg                                                                       0
# Student                                                                     26
# Tokyo                                                                        0
# Spambase                                                                     1
# Sonar                                                                        9
#
#                                           Tempo de execução                \
#                             Random Forest    Neural Network Random Forest
# Banknote                                8        141.178057    140.949971
# mammographic_masses                    17        104.350760    101.468797
# Room Occupancy                          0        153.161432    146.928882
# liver disorders_bupa                    3        135.812516    136.577896
# Monk_1                                 24          9.087778      6.621997
# Monk_2                                 31          9.302449      6.820625
# Monk_3                                 28          9.749496      6.913668
# Vertebral_2C                            2        140.843718    144.343818
# Diabetes                                8        162.025412    158.994113
# Breast Cancer Coimbra                   2        145.567600    143.835234
# Heart                                   5        168.597033    173.003850
# Heart_2                                 3        162.596136    152.121104
# EEg                                     1        263.851723    287.367322
# Australian                             10        662.409290    170.314212
# Votes_Congressional                     0         57.573072     51.140794
# German                                  2        253.193645    223.357106
# Mobile Price Classification            12        144.199227    150.504338
# twonorm                                 2        576.958079    586.009112
# KC2                                     1        354.907701    607.911204
# HELOC                                   0        517.143132    454.813778
# titanic                                 9         87.254891     90.875795
# Phishing                                0        441.759608    452.906020
# Breast Cancer Wisconsin                 0        535.944079    833.401842
# Ionosfera                               0        794.978922    830.841133
# Horse colic                             0        254.491596    229.007077
# Churn                                   0        441.840517    422.599502
# Biodeg                                  0       1205.567920    981.805070
# Student                                 9        203.134795    186.345053
# Tokyo                                   0        937.520761   1261.046824
# Spambase                                0        819.483918   1116.299825
# Sonar                                   0        390.911860    579.041518
#
#                             Proporção entre relações satisfeitas/analisadas  \
#                                                              Neural Network
# Banknote                                                          66.666667
# mammographic_masses                                               55.000000
# Room Occupancy                                                    63.492063
# liver disorders_bupa                                              57.142857
# Monk_1                                                           100.000000
# Monk_2                                                           100.000000
# Monk_3                                                           100.000000
# Vertebral_2C                                                      55.102041
# Diabetes                                                          52.941176
# Breast Cancer Coimbra                                             63.333333
# Heart                                                             73.529412
# Heart_2                                                           73.076923
# EEg                                                               55.882353
# Australian                                                       100.000000
# Votes_Congressional                                               85.437542
# German                                                            74.371069
# Mobile Price Classification                                      100.000000
# twonorm                                                           77.728285
# KC2                                                               81.481481
# HELOC                                                             54.726368
# titanic                                                           66.071429
# Phishing                                                          60.552332
# Breast Cancer Wisconsin                                           58.333333
# Ionosfera                                                         72.118959
# Horse colic                                                       58.088235
# Churn                                                             60.681927
# Biodeg                                                            60.240964
# Student                                                           68.452381
# Tokyo                                                             67.924528
# Spambase                                                          78.414634
# Sonar                                                             94.230769
#
#
#                             Random Forest
# Banknote                        72.727273
# mammographic_masses             73.333333
# Room Occupancy                  66.666667
# liver disorders_bupa            70.270270
# Monk_1                         100.000000
# Monk_2                         100.000000
# Monk_3                         100.000000
# Vertebral_2C                    58.333333
# Diabetes                        60.606061
# Breast Cancer Coimbra           59.677419
# Heart                           76.136364
# Heart_2                         87.272727
# EEg                             67.701863
# Australian                      85.000000
# Votes_Congressional             76.207303
# German                          71.717172
# Mobile Price Classification    100.000000
# twonorm                         94.074074
# KC2                             58.421053
# HELOC                           63.888889
# titanic                         70.172414
# Phishing                        61.296542
# Breast Cancer Wisconsin         54.632283
# Ionosfera                       70.822943
# Horse colic                     53.125000
# Churn                           58.855961
# Biodeg                          55.799373
# Student                         64.480874
# Tokyo                           55.412425
# Spambase                        84.450063
# Sonar                           84.379295

# %%
for metric in df.columns.levels[0]:  # Iterar sobre as métricas

    vmin = df[metric].min().min()
    vmax = df[metric].max().max()

    fig, ax = plt.subplots(1, 1, figsize=(6, 10))  # ax, e não axes[0]

    sns.heatmap(
        df[df.index.isin(numerica)][metric],
        annot=True,
        cmap="YlGnBu",
        cbar_kws={'label': translated_metrics[metric]},
        fmt="g",
        vmin=vmin,
        vmax=vmax,
        ax=ax  # especifica explicitamente o Axes a ser usado
    )

    ax.set_xlabel('Black Box')

    # fig.suptitle(f'{metric}', fontsize=16)
    plt.subplots_adjust(wspace=0.5)

    plt.show()

# %%
df.to_parquet('df_all_plot.parquet')

# %%
zxc = pd.read_parquet("df_plot.parquet")
zxc
# Out:
#                                  Quantidade de instâncias contrafactuais  \
#                                                           Neural Network
# display_name
# Banknote (5)                                                         110
# mammographic_masses (6)                                              110
# Room Occupancy (6)                                                   110
# liver disorders_bupa (7)                                             110
# Monk_1 (7)                                                           110
# Monk_2 (7)                                                           110
# Monk_3 (7)                                                           110
# Vertebral_2C (7)                                                     110
# Diabetes (9)                                                         110
# Breast Cancer Coimbra (10)                                           110
# Heart (14)                                                           110
# Heart_2 (14)                                                         110
# EEg (15)                                                             110
# Australian (16)                                                      110
# Votes_Congressional (17)                                             110
# German (21)                                                          110
# Mobile Price Classification (21)                                     110
# twonorm (21)                                                         110
# KC2 (22)                                                             110
# HELOC (24)                                                           110
# titanic (27)                                                         110
# Phishing (31)                                                        110
# Breast Cancer Wisconsin (32)                                         110
# Ionosfera (35)                                                       110
# Horse colic (37)                                                     110
# Churn (41)                                                           110
# Biodeg (42)                                                          110
# Student (44)                                                         110
# Tokyo (45)                                                           110
# Spambase (58)                                                        110
# Sonar (61)                                                           110
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                               110
# mammographic_masses (6)                    110
# Room Occupancy (6)                         110
# liver disorders_bupa (7)                   110
# Monk_1 (7)                                 110
# Monk_2 (7)                                 110
# Monk_3 (7)                                 110
# Vertebral_2C (7)                           110
# Diabetes (9)                               110
# Breast Cancer Coimbra (10)                 110
# Heart (14)                                 110
# Heart_2 (14)                               110
# EEg (15)                                   110
# Australian (16)                            110
# Votes_Congressional (17)                   110
# German (21)                                110
# Mobile Price Classification (21)           110
# twonorm (21)                               110
# KC2 (22)                                   110
# HELOC (24)                                 110
# titanic (27)                               110
# Phishing (31)                              110
# Breast Cancer Wisconsin (32)               110
# Ionosfera (35)                             110
# Horse colic (37)                           110
# Churn (41)                                 110
# Biodeg (42)                                110
# Student (44)                               110
# Tokyo (45)                                 110
# Spambase (58)                              110
# Sonar (61)                                 110
#
#                                  Quantidade de relações causais na base de dados  \
#                                                                   Neural Network
# display_name
# Banknote (5)                                                                   6
# mammographic_masses (6)                                                        6
# Room Occupancy (6)                                                            10
# liver disorders_bupa (7)                                                      10
# Monk_1 (7)                                                                     0
# Monk_2 (7)                                                                     0
# Monk_3 (7)                                                                     0
# Vertebral_2C (7)                                                              11
# Diabetes (9)                                                                  16
# Breast Cancer Coimbra (10)                                                    15
# Heart (14)                                                                    27
# Heart_2 (14)                                                                  33
# EEg (15)                                                                      82
# Australian (16)                                                               30
# Votes_Congressional (17)                                                      69
# German (21)                                                                   69
# Mobile Price Classification (21)                                               4
# twonorm (21)                                                                 190
# KC2 (22)                                                                     184
# HELOC (24)                                                                   195
# titanic (27)                                                                  64
# Phishing (31)                                                                306
# Breast Cancer Wisconsin (32)                                                 351
# Ionosfera (35)                                                               306
# Horse colic (37)                                                             110
# Churn (41)                                                                   232
# Biodeg (42)                                                                  515
# Student (44)                                                                  99
# Tokyo (45)                                                                   424
# Spambase (58)                                                                370
# Sonar (61)                                                                   245
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                                 6
# mammographic_masses (6)                      6
# Room Occupancy (6)                          10
# liver disorders_bupa (7)                    10
# Monk_1 (7)                                   0
# Monk_2 (7)                                   0
# Monk_3 (7)                                   0
# Vertebral_2C (7)                            11
# Diabetes (9)                                16
# Breast Cancer Coimbra (10)                  15
# Heart (14)                                  27
# Heart_2 (14)                                33
# EEg (15)                                    82
# Australian (16)                             30
# Votes_Congressional (17)                    68
# German (21)                                 69
# Mobile Price Classification (21)             4
# twonorm (21)                               190
# KC2 (22)                                   184
# HELOC (24)                                 195
# titanic (27)                                64
# Phishing (31)                              306
# Breast Cancer Wisconsin (32)               351
# Ionosfera (35)                             306
# Horse colic (37)                           103
# Churn (41)                                 220
# Biodeg (42)                                515
# Student (44)                                97
# Tokyo (45)                                 424
# Spambase (58)                              370
# Sonar (61)                                 245
#
#                                  Quantidade de atributos modificados  \
#                                                       Neural Network
# display_name
# Banknote (5)                                                      43
# mammographic_masses (6)                                           57
# Room Occupancy (6)                                                62
# liver disorders_bupa (7)                                          45
# Monk_1 (7)                                                        52
# Monk_2 (7)                                                        53
# Monk_3 (7)                                                        42
# Vertebral_2C (7)                                                  62
# Diabetes (9)                                                      35
# Breast Cancer Coimbra (10)                                        39
# Heart (14)                                                        58
# Heart_2 (14)                                                      65
# EEg (15)                                                          41
# Australian (16)                                                    0
# Votes_Congressional (17)                                         452
# German (21)                                                      301
# Mobile Price Classification (21)                                 123
# twonorm (21)                                                     117
# KC2 (22)                                                          31
# HELOC (24)                                                       115
# titanic (27)                                                     316
# Phishing (31)                                                   1123
# Breast Cancer Wisconsin (32)                                      48
# Ionosfera (35)                                                    96
# Horse colic (37)                                                 163
# Churn (41)                                                       866
# Biodeg (42)                                                      113
# Student (44)                                                     231
# Tokyo (45)                                                        71
# Spambase (58)                                                    226
# Sonar (61)                                                       105
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                                30
# mammographic_masses (6)                     42
# Room Occupancy (6)                          45
# liver disorders_bupa (7)                    41
# Monk_1 (7)                                  42
# Monk_2 (7)                                  74
# Monk_3 (7)                                  48
# Vertebral_2C (7)                            43
# Diabetes (9)                                62
# Breast Cancer Coimbra (10)                  64
# Heart (14)                                  78
# Heart_2 (14)                                55
# EEg (15)                                    71
# Australian (16)                             41
# Votes_Congressional (17)                   282
# German (21)                                205
# Mobile Price Classification (21)            14
# twonorm (21)                               147
# KC2 (22)                                   169
# HELOC (24)                                  82
# titanic (27)                               453
# Phishing (31)                             1020
# Breast Cancer Wisconsin (32)               214
# Ionosfera (35)                             112
# Horse colic (37)                           287
# Churn (41)                                 357
# Biodeg (42)                                102
# Student (44)                               238
# Tokyo (45)                                 598
# Spambase (58)                              341
# Sonar (61)                                 749
#
#                                  Quantidade de instâncias contrafactuais causais  \
#                                                                   Neural Network
# display_name
# Banknote (5)                                                                  22
# mammographic_masses (6)                                                       30
# Room Occupancy (6)                                                            21
# liver disorders_bupa (7)                                                      14
# Monk_1 (7)                                                                    28
# Monk_2 (7)                                                                    22
# Monk_3 (7)                                                                    27
# Vertebral_2C (7)                                                              20
# Diabetes (9)                                                                  15
# Breast Cancer Coimbra (10)                                                    13
# Heart (14)                                                                    21
# Heart_2 (14)                                                                  29
# EEg (15)                                                                      17
# Australian (16)                                                                0
# Votes_Congressional (17)                                                      42
# German (21)                                                                   32
# Mobile Price Classification (21)                                              55
# twonorm (21)                                                                  20
# KC2 (22)                                                                      11
# HELOC (24)                                                                    15
# titanic (27)                                                                  73
# Phishing (31)                                                                 55
# Breast Cancer Wisconsin (32)                                                   6
# Ionosfera (35)                                                                15
# Horse colic (37)                                                              17
# Churn (41)                                                                    45
# Biodeg (42)                                                                   14
# Student (44)                                                                  58
# Tokyo (45)                                                                    16
# Spambase (58)                                                                 22
# Sonar (61)                                                                    25
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                                16
# mammographic_masses (6)                     23
# Room Occupancy (6)                          12
# liver disorders_bupa (7)                    11
# Monk_1 (7)                                  24
# Monk_2 (7)                                  31
# Monk_3 (7)                                  28
# Vertebral_2C (7)                            11
# Diabetes (9)                                20
# Breast Cancer Coimbra (10)                  19
# Heart (14)                                  18
# Heart_2 (14)                                15
# EEg (15)                                    15
# Australian (16)                             18
# Votes_Congressional (17)                    30
# German (21)                                 27
# Mobile Price Classification (21)            12
# twonorm (21)                                18
# KC2 (22)                                    17
# HELOC (24)                                  17
# titanic (27)                                69
# Phishing (31)                               50
# Breast Cancer Wisconsin (32)                18
# Ionosfera (35)                              11
# Horse colic (37)                            29
# Churn (41)                                  15
# Biodeg (42)                                 13
# Student (44)                                48
# Tokyo (45)                                  21
# Spambase (58)                               18
# Sonar (61)                                  35
#
#                                  Quantidade de relações causais analisadas  \
#                                                             Neural Network
# display_name
# Banknote (5)                                                            21
# mammographic_masses (6)                                                 20
# Room Occupancy (6)                                                      63
# liver disorders_bupa (7)                                                42
# Monk_1 (7)                                                               0
# Monk_2 (7)                                                               0
# Monk_3 (7)                                                               0
# Vertebral_2C (7)                                                        49
# Diabetes (9)                                                            17
# Breast Cancer Coimbra (10)                                              30
# Heart (14)                                                              34
# Heart_2 (14)                                                            26
# EEg (15)                                                                68
# Australian (16)                                                          0
# Votes_Congressional (17)                                              1497
# German (21)                                                            636
# Mobile Price Classification (21)                                        14
# twonorm (21)                                                           449
# KC2 (22)                                                                27
# HELOC (24)                                                             402
# titanic (27)                                                           336
# Phishing (31)                                                         9306
# Breast Cancer Wisconsin (32)                                           132
# Ionosfera (35)                                                         269
# Horse colic (37)                                                       272
# Churn (41)                                                            4194
# Biodeg (42)                                                            415
# Student (44)                                                           168
# Tokyo (45)                                                             106
# Spambase (58)                                                          820
# Sonar (61)                                                             104
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                                11
# mammographic_masses (6)                     15
# Room Occupancy (6)                          63
# liver disorders_bupa (7)                    37
# Monk_1 (7)                                   0
# Monk_2 (7)                                   0
# Monk_3 (7)                                   0
# Vertebral_2C (7)                            36
# Diabetes (9)                                66
# Breast Cancer Coimbra (10)                  62
# Heart (14)                                  88
# Heart_2 (14)                                55
# EEg (15)                                   161
# Australian (16)                             20
# Votes_Congressional (17)                   849
# German (21)                                396
# Mobile Price Classification (21)             0
# twonorm (21)                               675
# KC2 (22)                                   760
# HELOC (24)                                 180
# titanic (27)                               580
# Phishing (31)                             8299
# Breast Cancer Wisconsin (32)              1047
# Ionosfera (35)                             401
# Horse colic (37)                           512
# Churn (41)                                1451
# Biodeg (42)                                319
# Student (44)                               183
# Tokyo (45)                                4813
# Spambase (58)                             1582
# Sonar (61)                                2183
#
#                                  Quantidade de relações causais satisfeitas  \
#                                                              Neural Network
# display_name
# Banknote (5)                                                             14
# mammographic_masses (6)                                                  11
# Room Occupancy (6)                                                       40
# liver disorders_bupa (7)                                                 24
# Monk_1 (7)                                                                0
# Monk_2 (7)                                                                0
# Monk_3 (7)                                                                0
# Vertebral_2C (7)                                                         27
# Diabetes (9)                                                              9
# Breast Cancer Coimbra (10)                                               19
# Heart (14)                                                               25
# Heart_2 (14)                                                             19
# EEg (15)                                                                 38
# Australian (16)                                                           0
# Votes_Congressional (17)                                               1279
# German (21)                                                             473
# Mobile Price Classification (21)                                         14
# twonorm (21)                                                            349
# KC2 (22)                                                                 22
# HELOC (24)                                                              220
# titanic (27)                                                            222
# Phishing (31)                                                          5635
# Breast Cancer Wisconsin (32)                                             77
# Ionosfera (35)                                                          194
# Horse colic (37)                                                        158
# Churn (41)                                                             2545
# Biodeg (42)                                                             250
# Student (44)                                                            115
# Tokyo (45)                                                               72
# Spambase (58)                                                           643
# Sonar (61)                                                               98
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                                 8
# mammographic_masses (6)                     11
# Room Occupancy (6)                          42
# liver disorders_bupa (7)                    26
# Monk_1 (7)                                   0
# Monk_2 (7)                                   0
# Monk_3 (7)                                   0
# Vertebral_2C (7)                            21
# Diabetes (9)                                40
# Breast Cancer Coimbra (10)                  37
# Heart (14)                                  67
# Heart_2 (14)                                48
# EEg (15)                                   109
# Australian (16)                             17
# Votes_Congressional (17)                   647
# German (21)                                284
# Mobile Price Classification (21)             0
# twonorm (21)                               635
# KC2 (22)                                   444
# HELOC (24)                                 115
# titanic (27)                               407
# Phishing (31)                             5087
# Breast Cancer Wisconsin (32)               572
# Ionosfera (35)                             284
# Horse colic (37)                           272
# Churn (41)                                 854
# Biodeg (42)                                178
# Student (44)                               118
# Tokyo (45)                                2667
# Spambase (58)                             1336
# Sonar (61)                                1842
#
#                                  Quantidade de instâncias contrafactuais com um único atributo modificado  \
#                                                                                            Neural Network
# display_name
# Banknote (5)                                                                     10
# mammographic_masses (6)                                                          22
# Room Occupancy (6)                                                                3
# liver disorders_bupa (7)                                                          2
# Monk_1 (7)                                                                       28
# Monk_2 (7)                                                                       22
# Monk_3 (7)                                                                       27
# Vertebral_2C (7)                                                                  4
# Diabetes (9)                                                                      8
# Breast Cancer Coimbra (10)                                                        3
# Heart (14)                                                                       13
# Heart_2 (14)                                                                     17
# EEg (15)                                                                         10
# Australian (16)                                                                   0
# Votes_Congressional (17)                                                          0
# German (21)                                                                       0
# Mobile Price Classification (21)                                                 41
# twonorm (21)                                                                      1
# KC2 (22)                                                                          3
# HELOC (24)                                                                        3
# titanic (27)                                                                     14
# Phishing (31)                                                                     1
# Breast Cancer Wisconsin (32)                                                      0
# Ionosfera (35)                                                                    2
# Horse colic (37)                                                                  0
# Churn (41)                                                                        7
# Biodeg (42)                                                                       0
# Student (44)                                                                     26
# Tokyo (45)                                                                        0
# Spambase (58)                                                                     1
# Sonar (61)                                                                        9
#
#                                                Tempo de execução  \
#                                  Random Forest    Neural Network
# display_name
# Banknote (5)                                 8        141.178057
# mammographic_masses (6)                     17        104.350760
# Room Occupancy (6)                           0        153.161432
# liver disorders_bupa (7)                     3        135.812516
# Monk_1 (7)                                  24          9.087778
# Monk_2 (7)                                  31          9.302449
# Monk_3 (7)                                  28          9.749496
# Vertebral_2C (7)                             2        140.843718
# Diabetes (9)                                 8        162.025412
# Breast Cancer Coimbra (10)                   2        145.567600
# Heart (14)                                   5        168.597033
# Heart_2 (14)                                 3        162.596136
# EEg (15)                                     1        263.851723
# Australian (16)                             10        662.409290
# Votes_Congressional (17)                     0         57.573072
# German (21)                                  2        253.193645
# Mobile Price Classification (21)            12        144.199227
# twonorm (21)                                 2        576.958079
# KC2 (22)                                     1        354.907701
# HELOC (24)                                   0        517.143132
# titanic (27)                                 9         87.254891
# Phishing (31)                                0        441.759608
# Breast Cancer Wisconsin (32)                 0        535.944079
# Ionosfera (35)                               0        794.978922
# Horse colic (37)                             0        254.491596
# Churn (41)                                   0        441.840517
# Biodeg (42)                                  0       1205.567920
# Student (44)                                 9        203.134795
# Tokyo (45)                                   0        937.520761
# Spambase (58)                                0        819.483918
# Sonar (61)                                   0        390.911860
#
#                                                 \
#                                  Random Forest
# display_name
# Banknote (5)                        140.949971
# mammographic_masses (6)             101.468797
# Room Occupancy (6)                  146.928882
# liver disorders_bupa (7)            136.577896
# Monk_1 (7)                            6.621997
# Monk_2 (7)                            6.820625
# Monk_3 (7)                            6.913668
# Vertebral_2C (7)                    144.343818
# Diabetes (9)                        158.994113
# Breast Cancer Coimbra (10)          143.835234
# Heart (14)                          173.003850
# Heart_2 (14)                        152.121104
# EEg (15)                            287.367322
# Australian (16)                     170.314212
# Votes_Congressional (17)             51.140794
# German (21)                         223.357106
# Mobile Price Classification (21)    150.504338
# twonorm (21)                        586.009112
# KC2 (22)                            607.911204
# HELOC (24)                          454.813778
# titanic (27)                         90.875795
# Phishing (31)                       452.906020
# Breast Cancer Wisconsin (32)        833.401842
# Ionosfera (35)                      830.841133
# Horse colic (37)                    229.007077
# Churn (41)                          422.599502
# Biodeg (42)                         981.805070
# Student (44)                        186.345053
# Tokyo (45)                         1261.046824
# Spambase (58)                      1116.299825
# Sonar (61)                          579.041518
#
#                                  Proporção entre relações satisfeitas/analisadas  \
#                                                                   Neural Network
# display_name
# Banknote (5)                                                           66.666667
# mammographic_masses (6)                                                55.000000
# Room Occupancy (6)                                                     63.492063
# liver disorders_bupa (7)                                               57.142857
# Monk_1 (7)                                                            100.000000
# Monk_2 (7)                                                            100.000000
# Monk_3 (7)                                                            100.000000
# Vertebral_2C (7)                                                       55.102041
# Diabetes (9)                                                           52.941176
# Breast Cancer Coimbra (10)                                             63.333333
# Heart (14)                                                             73.529412
# Heart_2 (14)                                                           73.076923
# EEg (15)                                                               55.882353
# Australian (16)                                                       100.000000
# Votes_Congressional (17)                                               85.437542
# German (21)                                                            74.371069
# Mobile Price Classification (21)                                      100.000000
# twonorm (21)                                                           77.728285
# KC2 (22)                                                               81.481481
# HELOC (24)                                                             54.726368
# titanic (27)                                                           66.071429
# Phishing (31)                                                          60.552332
# Breast Cancer Wisconsin (32)                                           58.333333
# Ionosfera (35)                                                         72.118959
# Horse colic (37)                                                       58.088235
# Churn (41)                                                             60.681927
# Biodeg (42)                                                            60.240964
# Student (44)                                                           68.452381
# Tokyo (45)                                                             67.924528
# Spambase (58)                                                          78.414634
# Sonar (61)                                                             94.230769
#
#
#                                  Random Forest
# display_name
# Banknote (5)                         72.727273
# mammographic_masses (6)              73.333333
# Room Occupancy (6)                   66.666667
# liver disorders_bupa (7)             70.270270
# Monk_1 (7)                          100.000000
# Monk_2 (7)                          100.000000
# Monk_3 (7)                          100.000000
# Vertebral_2C (7)                     58.333333
# Diabetes (9)                         60.606061
# Breast Cancer Coimbra (10)           59.677419
# Heart (14)                           76.136364
# Heart_2 (14)                         87.272727
# EEg (15)                             67.701863
# Australian (16)                      85.000000
# Votes_Congressional (17)             76.207303
# German (21)                          71.717172
# Mobile Price Classification (21)    100.000000
# twonorm (21)                         94.074074
# KC2 (22)                             58.421053
# HELOC (24)                           63.888889
# titanic (27)                         70.172414
# Phishing (31)                        61.296542
# Breast Cancer Wisconsin (32)         54.632283
# Ionosfera (35)                       70.822943
# Horse colic (37)                     53.125000
# Churn (41)                           58.855961
# Biodeg (42)                          55.799373
# Student (44)                         64.480874
# Tokyo (45)                           55.412425
# Spambase (58)                        84.450063
# Sonar (61)                           84.379295

# %%
size_list = [('Banknote', 5),
 ('mammographic_masses', 6),
 ('Room Occupancy', 6),
 ('liver disorders_bupa', 7),
 ('Monk_1', 7),
 ('Monk_2', 7),
 ('Monk_3', 7),
 ('Vertebral_2C', 7),
 ('Diabetes', 9),
 ('Breast Cancer Coimbra', 10),
 ('Heart', 14),
 ('Heart_2', 14),
 ('EEg', 15),
 ('Australian', 16),
 ('Votes_Congressional', 17),
 ('German', 21),
 ('Mobile Price Classification', 21),
 ('twonorm', 21),
 ('KC2', 22),
 ('HELOC', 24),
 ('titanic', 27),
 ('Phishing', 31),
 ('Breast Cancer Wisconsin', 32),
 ('Ionosfera', 35),
 ('Horse colic', 37),
 ('Churn', 41),
 ('Biodeg', 42),
 ('Student', 44),
 ('Tokyo', 45),
 ('Spambase', 58),
 ('Sonar', 61),
 ('Musk', 165)]

# %%
df = pd.read_parquet("df_all_plot.parquet")
df
# Out:
#                             Quantidade de instâncias contrafactuais  \
#                                                      Neural Network
# Banknote                                                        110
# mammographic_masses                                             110
# Room Occupancy                                                  110
# liver disorders_bupa                                            110
# Monk_1                                                          110
# Monk_2                                                          110
# Monk_3                                                          110
# Vertebral_2C                                                    110
# Diabetes                                                        110
# Breast Cancer Coimbra                                           110
# Heart                                                           110
# Heart_2                                                         110
# EEg                                                             110
# Australian                                                      110
# Votes_Congressional                                             110
# German                                                          110
# Mobile Price Classification                                     110
# twonorm                                                         110
# KC2                                                             110
# HELOC                                                           110
# titanic                                                         110
# Phishing                                                        110
# Breast Cancer Wisconsin                                         110
# Ionosfera                                                       110
# Horse colic                                                     110
# Churn                                                           110
# Biodeg                                                          110
# Student                                                         110
# Tokyo                                                           110
# Spambase                                                        110
# Sonar                                                           110
#
#                                            \
#                             Random Forest
# Banknote                              110
# mammographic_masses                   110
# Room Occupancy                        110
# liver disorders_bupa                  110
# Monk_1                                110
# Monk_2                                110
# Monk_3                                110
# Vertebral_2C                          110
# Diabetes                              110
# Breast Cancer Coimbra                 110
# Heart                                 110
# Heart_2                               110
# EEg                                   110
# Australian                            110
# Votes_Congressional                   110
# German                                110
# Mobile Price Classification           110
# twonorm                               110
# KC2                                   110
# HELOC                                 110
# titanic                               110
# Phishing                              110
# Breast Cancer Wisconsin               110
# Ionosfera                             110
# Horse colic                           110
# Churn                                 110
# Biodeg                                110
# Student                               110
# Tokyo                                 110
# Spambase                              110
# Sonar                                 110
#
#                             Quantidade de relações causais na base de dados  \
#                                                              Neural Network
# Banknote                                                                  6
# mammographic_masses                                                       6
# Room Occupancy                                                           10
# liver disorders_bupa                                                     10
# Monk_1                                                                    0
# Monk_2                                                                    0
# Monk_3                                                                    0
# Vertebral_2C                                                             11
# Diabetes                                                                 16
# Breast Cancer Coimbra                                                    15
# Heart                                                                    27
# Heart_2                                                                  33
# EEg                                                                      82
# Australian                                                               30
# Votes_Congressional                                                      69
# German                                                                   69
# Mobile Price Classification                                               4
# twonorm                                                                 190
# KC2                                                                     184
# HELOC                                                                   195
# titanic                                                                  64
# Phishing                                                                306
# Breast Cancer Wisconsin                                                 351
# Ionosfera                                                               306
# Horse colic                                                             110
# Churn                                                                   232
# Biodeg                                                                  515
# Student                                                                  99
# Tokyo                                                                   424
# Spambase                                                                370
# Sonar                                                                   245
#
#                                           Quantidade de atributos modificados  \
#                             Random Forest                      Neural Network
# Banknote                                6                                  43
# mammographic_masses                     6                                  57
# Room Occupancy                         10                                  62
# liver disorders_bupa                   10                                  45
# Monk_1                                  0                                  52
# Monk_2                                  0                                  53
# Monk_3                                  0                                  42
# Vertebral_2C                           11                                  62
# Diabetes                               16                                  35
# Breast Cancer Coimbra                  15                                  39
# Heart                                  27                                  58
# Heart_2                                33                                  65
# EEg                                    82                                  41
# Australian                             30                                   0
# Votes_Congressional                    68                                 452
# German                                 69                                 301
# Mobile Price Classification             4                                 123
# twonorm                               190                                 117
# KC2                                   184                                  31
# HELOC                                 195                                 115
# titanic                                64                                 316
# Phishing                              306                                1123
# Breast Cancer Wisconsin               351                                  48
# Ionosfera                             306                                  96
# Horse colic                           103                                 163
# Churn                                 220                                 866
# Biodeg                                515                                 113
# Student                                97                                 231
# Tokyo                                 424                                  71
# Spambase                              370                                 226
# Sonar                                 245                                 105
#
#                                            \
#                             Random Forest
# Banknote                               30
# mammographic_masses                    42
# Room Occupancy                         45
# liver disorders_bupa                   41
# Monk_1                                 42
# Monk_2                                 74
# Monk_3                                 48
# Vertebral_2C                           43
# Diabetes                               62
# Breast Cancer Coimbra                  64
# Heart                                  78
# Heart_2                                55
# EEg                                    71
# Australian                             41
# Votes_Congressional                   282
# German                                205
# Mobile Price Classification            14
# twonorm                               147
# KC2                                   169
# HELOC                                  82
# titanic                               453
# Phishing                             1020
# Breast Cancer Wisconsin               214
# Ionosfera                             112
# Horse colic                           287
# Churn                                 357
# Biodeg                                102
# Student                               238
# Tokyo                                 598
# Spambase                              341
# Sonar                                 749
#
#                             Quantidade de instâncias contrafactuais causais  \
#                                                              Neural Network
# Banknote                                                                 22
# mammographic_masses                                                      30
# Room Occupancy                                                           21
# liver disorders_bupa                                                     14
# Monk_1                                                                   28
# Monk_2                                                                   22
# Monk_3                                                                   27
# Vertebral_2C                                                             20
# Diabetes                                                                 15
# Breast Cancer Coimbra                                                    13
# Heart                                                                    21
# Heart_2                                                                  29
# EEg                                                                      17
# Australian                                                                0
# Votes_Congressional                                                      42
# German                                                                   32
# Mobile Price Classification                                              55
# twonorm                                                                  20
# KC2                                                                      11
# HELOC                                                                    15
# titanic                                                                  73
# Phishing                                                                 55
# Breast Cancer Wisconsin                                                   6
# Ionosfera                                                                15
# Horse colic                                                              17
# Churn                                                                    45
# Biodeg                                                                   14
# Student                                                                  58
# Tokyo                                                                    16
# Spambase                                                                 22
# Sonar                                                                    25
#
#                                            \
#                             Random Forest
# Banknote                               16
# mammographic_masses                    23
# Room Occupancy                         12
# liver disorders_bupa                   11
# Monk_1                                 24
# Monk_2                                 31
# Monk_3                                 28
# Vertebral_2C                           11
# Diabetes                               20
# Breast Cancer Coimbra                  19
# Heart                                  18
# Heart_2                                15
# EEg                                    15
# Australian                             18
# Votes_Congressional                    30
# German                                 27
# Mobile Price Classification            12
# twonorm                                18
# KC2                                    17
# HELOC                                  17
# titanic                                69
# Phishing                               50
# Breast Cancer Wisconsin                18
# Ionosfera                              11
# Horse colic                            29
# Churn                                  15
# Biodeg                                 13
# Student                                48
# Tokyo                                  21
# Spambase                               18
# Sonar                                  35
#
#                             Quantidade de relações causais analisadas  \
#                                                        Neural Network
# Banknote                                                           21
# mammographic_masses                                                20
# Room Occupancy                                                     63
# liver disorders_bupa                                               42
# Monk_1                                                              0
# Monk_2                                                              0
# Monk_3                                                              0
# Vertebral_2C                                                       49
# Diabetes                                                           17
# Breast Cancer Coimbra                                              30
# Heart                                                              34
# Heart_2                                                            26
# EEg                                                                68
# Australian                                                          0
# Votes_Congressional                                              1497
# German                                                            636
# Mobile Price Classification                                        14
# twonorm                                                           449
# KC2                                                                27
# HELOC                                                             402
# titanic                                                           336
# Phishing                                                         9306
# Breast Cancer Wisconsin                                           132
# Ionosfera                                                         269
# Horse colic                                                       272
# Churn                                                            4194
# Biodeg                                                            415
# Student                                                           168
# Tokyo                                                             106
# Spambase                                                          820
# Sonar                                                             104
#
#                                            \
#                             Random Forest
# Banknote                               11
# mammographic_masses                    15
# Room Occupancy                         63
# liver disorders_bupa                   37
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           36
# Diabetes                               66
# Breast Cancer Coimbra                  62
# Heart                                  88
# Heart_2                                55
# EEg                                   161
# Australian                             20
# Votes_Congressional                   849
# German                                396
# Mobile Price Classification             0
# twonorm                               675
# KC2                                   760
# HELOC                                 180
# titanic                               580
# Phishing                             8299
# Breast Cancer Wisconsin              1047
# Ionosfera                             401
# Horse colic                           512
# Churn                                1451
# Biodeg                                319
# Student                               183
# Tokyo                                4813
# Spambase                             1582
# Sonar                                2183
#
#                             Quantidade de relações causais satisfeitas  \
#                                                         Neural Network
# Banknote                                                            14
# mammographic_masses                                                 11
# Room Occupancy                                                      40
# liver disorders_bupa                                                24
# Monk_1                                                               0
# Monk_2                                                               0
# Monk_3                                                               0
# Vertebral_2C                                                        27
# Diabetes                                                             9
# Breast Cancer Coimbra                                               19
# Heart                                                               25
# Heart_2                                                             19
# EEg                                                                 38
# Australian                                                           0
# Votes_Congressional                                               1279
# German                                                             473
# Mobile Price Classification                                         14
# twonorm                                                            349
# KC2                                                                 22
# HELOC                                                              220
# titanic                                                            222
# Phishing                                                          5635
# Breast Cancer Wisconsin                                             77
# Ionosfera                                                          194
# Horse colic                                                        158
# Churn                                                             2545
# Biodeg                                                             250
# Student                                                            115
# Tokyo                                                               72
# Spambase                                                           643
# Sonar                                                               98
#
#                                            \
#                             Random Forest
# Banknote                                8
# mammographic_masses                    11
# Room Occupancy                         42
# liver disorders_bupa                   26
# Monk_1                                  0
# Monk_2                                  0
# Monk_3                                  0
# Vertebral_2C                           21
# Diabetes                               40
# Breast Cancer Coimbra                  37
# Heart                                  67
# Heart_2                                48
# EEg                                   109
# Australian                             17
# Votes_Congressional                   647
# German                                284
# Mobile Price Classification             0
# twonorm                               635
# KC2                                   444
# HELOC                                 115
# titanic                               407
# Phishing                             5087
# Breast Cancer Wisconsin               572
# Ionosfera                             284
# Horse colic                           272
# Churn                                 854
# Biodeg                                178
# Student                               118
# Tokyo                                2667
# Spambase                             1336
# Sonar                                1842
#
#                             Quantidade de instâncias contrafactuais com um único atributo modificado  \
#                                                                                       Neural Network
# Banknote                                                                    10
# mammographic_masses                                                         22
# Room Occupancy                                                               3
# liver disorders_bupa                                                         2
# Monk_1                                                                      28
# Monk_2                                                                      22
# Monk_3                                                                      27
# Vertebral_2C                                                                 4
# Diabetes                                                                     8
# Breast Cancer Coimbra                                                        3
# Heart                                                                       13
# Heart_2                                                                     17
# EEg                                                                         10
# Australian                                                                   0
# Votes_Congressional                                                          0
# German                                                                       0
# Mobile Price Classification                                                 41
# twonorm                                                                      1
# KC2                                                                          3
# HELOC                                                                        3
# titanic                                                                     14
# Phishing                                                                     1
# Breast Cancer Wisconsin                                                      0
# Ionosfera                                                                    2
# Horse colic                                                                  0
# Churn                                                                        7
# Biodeg                                                                       0
# Student                                                                     26
# Tokyo                                                                        0
# Spambase                                                                     1
# Sonar                                                                        9
#
#                                           Tempo de execução                \
#                             Random Forest    Neural Network Random Forest
# Banknote                                8        141.178057    140.949971
# mammographic_masses                    17        104.350760    101.468797
# Room Occupancy                          0        153.161432    146.928882
# liver disorders_bupa                    3        135.812516    136.577896
# Monk_1                                 24          9.087778      6.621997
# Monk_2                                 31          9.302449      6.820625
# Monk_3                                 28          9.749496      6.913668
# Vertebral_2C                            2        140.843718    144.343818
# Diabetes                                8        162.025412    158.994113
# Breast Cancer Coimbra                   2        145.567600    143.835234
# Heart                                   5        168.597033    173.003850
# Heart_2                                 3        162.596136    152.121104
# EEg                                     1        263.851723    287.367322
# Australian                             10        662.409290    170.314212
# Votes_Congressional                     0         57.573072     51.140794
# German                                  2        253.193645    223.357106
# Mobile Price Classification            12        144.199227    150.504338
# twonorm                                 2        576.958079    586.009112
# KC2                                     1        354.907701    607.911204
# HELOC                                   0        517.143132    454.813778
# titanic                                 9         87.254891     90.875795
# Phishing                                0        441.759608    452.906020
# Breast Cancer Wisconsin                 0        535.944079    833.401842
# Ionosfera                               0        794.978922    830.841133
# Horse colic                             0        254.491596    229.007077
# Churn                                   0        441.840517    422.599502
# Biodeg                                  0       1205.567920    981.805070
# Student                                 9        203.134795    186.345053
# Tokyo                                   0        937.520761   1261.046824
# Spambase                                0        819.483918   1116.299825
# Sonar                                   0        390.911860    579.041518
#
#                             Proporção entre relações satisfeitas/analisadas  \
#                                                              Neural Network
# Banknote                                                          66.666667
# mammographic_masses                                               55.000000
# Room Occupancy                                                    63.492063
# liver disorders_bupa                                              57.142857
# Monk_1                                                           100.000000
# Monk_2                                                           100.000000
# Monk_3                                                           100.000000
# Vertebral_2C                                                      55.102041
# Diabetes                                                          52.941176
# Breast Cancer Coimbra                                             63.333333
# Heart                                                             73.529412
# Heart_2                                                           73.076923
# EEg                                                               55.882353
# Australian                                                       100.000000
# Votes_Congressional                                               85.437542
# German                                                            74.371069
# Mobile Price Classification                                      100.000000
# twonorm                                                           77.728285
# KC2                                                               81.481481
# HELOC                                                             54.726368
# titanic                                                           66.071429
# Phishing                                                          60.552332
# Breast Cancer Wisconsin                                           58.333333
# Ionosfera                                                         72.118959
# Horse colic                                                       58.088235
# Churn                                                             60.681927
# Biodeg                                                            60.240964
# Student                                                           68.452381
# Tokyo                                                             67.924528
# Spambase                                                          78.414634
# Sonar                                                             94.230769
#
#
#                             Random Forest
# Banknote                        72.727273
# mammographic_masses             73.333333
# Room Occupancy                  66.666667
# liver disorders_bupa            70.270270
# Monk_1                         100.000000
# Monk_2                         100.000000
# Monk_3                         100.000000
# Vertebral_2C                    58.333333
# Diabetes                        60.606061
# Breast Cancer Coimbra           59.677419
# Heart                           76.136364
# Heart_2                         87.272727
# EEg                             67.701863
# Australian                      85.000000
# Votes_Congressional             76.207303
# German                          71.717172
# Mobile Price Classification    100.000000
# twonorm                         94.074074
# KC2                             58.421053
# HELOC                           63.888889
# titanic                         70.172414
# Phishing                        61.296542
# Breast Cancer Wisconsin         54.632283
# Ionosfera                       70.822943
# Horse colic                     53.125000
# Churn                           58.855961
# Biodeg                          55.799373
# Student                         64.480874
# Tokyo                           55.412425
# Spambase                        84.450063
# Sonar                           84.379295

# %%
# 1. Transformar a lista em dicionário
size_dict = {name: size for name, size in size_list}

# 2. Criar nova coluna de labels formatados: "Nome (tamanho)"
df_plot = df.copy()  # Evita modificar o original
df_plot['display_name'] = [f"{idx} ({size_dict.get(idx, '?')})" for idx in df_plot.index]

# # 3. Substituir o índice pela nova coluna para exibição
df_plot = df_plot.set_index('display_name')

# df_plot = pd.read_parquet("df_plot.parquet")

# 4. Plot
for metric in df_plot.columns.levels[0]:
    vmin = df_plot[metric].min().min()
    vmax = df_plot[metric].max().max()

    fig, ax = plt.subplots(1, 1, figsize=(6, 10))

    sns.heatmap(
        df_plot[df_plot.index.isin([f"{name} ({size_dict.get(name, '?')})" for name in numerica])][metric],
        annot=True,
        cmap="YlGnBu",
        cbar_kws={'label': translated_metrics[metric]},
        fmt="g",
        vmin=vmin,
        vmax=vmax,
        ax=ax
    )

    ax.set_xlabel('Black Box', fontsize=10)
    ax.set_ylabel('Dataset (size)', fontsize=10)

    # fig.suptitle(f'{metric}', fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 15
#      11 # df_plot = pd.read_parquet("df_plot.parquet")
#      12
#      13 # 4. Plot
#      14 for metric in df_plot.columns.levels[0]:
# ---> 15     vmin = df_plot[metric].min().min()
#      16     vmax = df_plot[metric].max().max()
#      18     fig, ax = plt.subplots(1, 1, figsize=(6, 10))
#
# File c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4101, in DataFrame.__getitem__(self, key)
#    4099 if is_single_key:
#    4100     if self.columns.nlevels > 1:
# -> 4101         return self._getitem_multilevel(key)
#    4102     indexer = self.columns.get_loc(key)
#    4103     if is_integer(indexer):
#
# File c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4159, in DataFrame._getitem_multilevel(self, key)
#    4157 def _getitem_multilevel(self, key):
#    4158     # self.columns is a MultiIndex
# -> 4159     loc = self.columns.get_loc(key)
#    4160     if isinstance(loc, (slice, np.ndarray)):
#    4161         new_columns = self.columns[loc]
#
# File c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:3040, in MultiIndex.get_loc(self, key)
#    3037     return mask
#    3039 if not isinstance(key, tuple):
# -> 3040     loc = self._get_level_indexer(key, level=0)
#    3041     return _maybe_to_slice(loc)
#    3043 keylen = len(key)
#
# File c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:3404, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3400     locs = np.asarray(level_codes == idx, dtype=bool)
#    3402     if not locs.any():
#    3403         # The label is present in self.levels[level] but unused:
# -> 3404         raise KeyError(key)
#    3405     return locs
#    3407 if isinstance(idx, slice):
#    3408     # e.g. test_partial_string_timestamp_multiindex
#
# KeyError: 'display_name'

# %%
for metric in df.columns.levels[0]:
    vmin = df[metric].min().min()
    vmax = df[metric].max().max()

    fig, ax = plt.subplots(1, 1, figsize=(12, 8))  # Aumentado para melhor visibilidade

    sns.heatmap(
        df[df.index.isin([f"{name} ({size_dict.get(name, '?')})" for name in numerica])][metric],
        annot=True,
        annot_kws={"size": 16},  # Tamanho dos números dentro das células
        cmap="YlGnBu",
        cbar_kws={'label': translated_metrics[metric]},
        fmt="g",
        vmin=vmin,
        vmax=vmax,
        ax=ax
    )

    # ax.set_title('Numerical Bases', fontsize=16)
    ax.set_xlabel('Black Box', fontsize=16)
    ax.set_ylabel('Dataset (size)', fontsize=16)

    ax.tick_params(axis='both', which='major', labelsize=16)  # Tamanho dos ticks
    ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=16)  # Y labels legíveis
    # ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=12)  # X labels

    # fig.suptitle(f'{metric}', fontsize=18)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()
# Out:
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# c:\Users\OmarKrauss\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
